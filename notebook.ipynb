# %% [markdown]
# ### Read dataset_anime_romance.csv in database
#
# Pada part ini, saya coba baca file data anime.csv menggunakan pandas dan saya coba tampilkan 10 data teratas dan 10 data terbawah

# %%
# baca data dari file CSV

import pandas as pd

df = pd.read_csv('database/dataset_anime_romance.csv')

tabel_rapi = pd.concat([df.head(), df.tail()])

tabel_rapi
# Out:
#       mal_id                                              title  score  \
# 0      11757                                   Sword Art Online   7.22
# 1      23273                            Shigatsu wa Kimi no Uso   8.64
# 2       4224                                          Toradora!   8.04
# 3      21881                                Sword Art Online II   6.72
# 4      37450  Seishun Buta Yarou wa Bunny Girl Senpai no Yum...   8.23
# 2252   61003                                             Seesaw    NaN
# 2253   62952                          Xian Jian Qi Xia Zhuan Si    NaN
# 2254   62402                                            Dongzhi    NaN
# 2255   63308                                 Tasogare ni Encore    NaN
# 2256   63313                       Zui Hou Jue Ding Ai Shang Ni    NaN
#
#                                    genres  \
# 0     Action, Adventure, Fantasy, Romance
# 1                          Drama, Romance
# 2                          Drama, Romance
# 3     Action, Adventure, Fantasy, Romance
# 4            Drama, Romance, Supernatural
# 2252                              Romance
# 2253      Action, Drama, Fantasy, Romance
# 2254                       Drama, Romance
# 2255                       Drama, Romance
# 2256                      Comedy, Romance
#
#                                                synopsis  \
# 0     Ever since the release of the innovative Nerve...
# 1     Kousei Arima is a child prodigy known as the "...
# 2     Ryuuji Takasu is a gentle high school student ...
# 3     A year after escaping Sword Art Online, Kazuto...
# 4     The rare and inexplicable Puberty Syndrome is ...
# 2252          Music video for the song Seesaw by tuki..
# 2253  For the sake of their cultivation endeavors, t...
# 2254  Shortly before he died, he had dated his old l...
# 2255  Music video for the song Tasogare ni Encore by...
# 2256  Two strangers, both proposed marriage to their...
#
#                                               image_url   type  episodes  \
# 0     https://cdn.myanimelist.net/images/anime/11/39...     TV      25.0
# 1     https://cdn.myanimelist.net/images/anime/1405/...     TV      22.0
# 2     https://cdn.myanimelist.net/images/anime/13/22...     TV      25.0
# 3     https://cdn.myanimelist.net/images/anime/1223/...     TV      24.0
# 4     https://cdn.myanimelist.net/images/anime/1301/...     TV      13.0
# 2252  https://cdn.myanimelist.net/images/anime/1773/...  Music       1.0
# 2253  https://cdn.myanimelist.net/images/anime/1440/...    ONA       NaN
# 2254  https://cdn.myanimelist.net/images/anime/1177/...  Movie       1.0
# 2255  https://cdn.myanimelist.net/images/anime/1022/...  Music       1.0
# 2256  https://cdn.myanimelist.net/images/anime/1404/...     TV      13.0
#
#       members                                                url
# 0     3262676  https://myanimelist.net/anime/11757/Sword_Art_...
# 1     2386394  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2     2339344        https://myanimelist.net/anime/4224/Toradora
# 3     2090814  https://myanimelist.net/anime/21881/Sword_Art_...
# 4     1924158  https://myanimelist.net/anime/37450/Seishun_Bu...
# 2252       69         https://myanimelist.net/anime/61003/Seesaw
# 2253       66  https://myanimelist.net/anime/62952/Xian_Jian_...
# 2254       59        https://myanimelist.net/anime/62402/Dongzhi
# 2255       28  https://myanimelist.net/anime/63308/Tasogare_n...
# 2256        0  https://myanimelist.net/anime/63313/Zui_Hou_Ju...

# %% [markdown]
# ### Analisis Awal Struktur Data
# Berdasarkan tinjauan terhadap sampel data teratas (head) dan terbawah (tail), teridentifikasi beberapa karakteristik dataset yang memerlukan penanganan khusus sebelum pemrosesan lebih lanjut:
#
# 1. Kelengkapan Atribut: Data pada peringkat atas (populer) memiliki atribut yang lengkap. Namun, pada data peringkat bawah, ditemukan nilai kosong (missing values/NaN) pada kolom krusial synopsis dan score. Ketiadaan sinopsis pada entri tertentu (contoh: Di Ling Ai, Fukusuke) akan menghambat proses ekstraksi fitur berbasis teks.
# 2. Variasi Tipe Konten: Kolom type menunjukkan inkonsistensi format tontonan. Selain format naratif standar seperti 'TV' dan 'Movie', terdapat entri bertipe 'Music' (contoh: Into Me, Baby). Entri ini umumnya berupa video musik berdurasi pendek yang tidak relevan untuk sistem rekomendasi serial anime.
# 3. Distribusi Skor: Terdapat disparitas nilai pada kolom score, di mana entri baru atau kurang populer belum memiliki nilai rating (NaN), yang perlu diantisipasi saat melakukan pengurutan rekomendasi.
#
# ### Kesimpulan Awal
# Diperlukan tahap pembersihan data (data cleaning) untuk mengeliminasi baris dengan sinopsis kosong dan memfilter tipe konten non-naratif agar relevansi model tetap terjaga.

# %%
# pembersihan data

# NaN pada kolom synopsis dan filter tipe anime
df_clean = df.dropna(subset=['synopsis'])

# Buang data dengan tipe selain TV, Movie, OVA, ONA, Special
df_clean = df_clean[df_clean['type'].isin(['TV', 'Movie', 'OVA', 'ONA', 'Special'])]

df_clean = df_clean.reset_index(drop=True)

print("Hasil pembersihan data:")
print(f"Jumlah data awal  : {len(df)}")
print(f"Jumlah data akhir : {len(df_clean)}")
print(f"Data yang dibuang : {len(df) - len(df_clean)}")
# Out:
# Hasil pembersihan data:
# Jumlah data awal  : 2257
# Jumlah data akhir : 1972
# Data yang dibuang : 285
